# %% [markdown]
# <a href="https://colab.research.google.com/github/Mustafaieva/03_Strings/blob/master/Example%20%237..ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#include <stdio.h>

int main()
{
    char str[100];
    char wrd[20];

    printf("Input the string: ");
    fgets(str, 100, stdin);

    printf("The search word: ");
    scanf("%20s", wrd);

    printf("The length of the string:%d\n", N(str));
    printf("Length of searched word: %d\n", N(wrd));

    int exist=fonk(str, wrd);
    if (exist==0)
    {
        printf("The word is not found.\n");
    }
    else
    {
        printf("The word is found.\n");
    }



return 0;
}

int N(const char *s)
{
    int i;
    for (i=0; s[i]!='\0'; i++)
    {

    }
    return i;
}


int fonk(const char *s, const char *wrd)
{
    int i, j;
    int s_n=N(s);
    int wrd_N=N(wrd);

    for (i=0; i<=s_n-wrd_N; i++)
    {
        for (j=0; j<wrd_N; j++)
        {
            if (s[i+j]!=wrd[i])
            break;
        }
        if (j==wrd_N)
            return 1;
    }
}

# %% [markdown]
# #Search for a string in the string
#
# In this example we entered the string and the search word:
#
# > printf("Input the string: ");
#
#      fgets(str, 100, stdin);
#
#     printf("The search word: ");
#
#     scanf("%20s", wrd);
#
# We specified a new variable 'exist' that is equal to the function 'fonk(str, wrd)';
#
# >  int exist=fonk(str, wrd);
#
# If the value is false, that is, the search word is not found the string, then printed the:
#
# >   if (exist==0)
#     {
#         printf("The search word is not found.\n");
#     }
#
# Otherwise, if the word is found, then printed the:
#
# >  else
#     {
#         printf("The word is found.\n");
#     }
#
#     In function 'int N' the action is not performed and it is considered.
#
#
#    In function  ' int string_ara '' we are looking for the  word in the string:
#
#
# > for (i=0; i<=s_n-wrd_N; i++)
#     {
#         for (j=0; j<wrd_N; j++)
#        ....}
#
#  If j == wrd_N: j terminated and wrd_N is the same:
#
# >  if (j==wrd_N)
